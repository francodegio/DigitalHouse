# %% [markdown]
# # Desafio Properati
#
# ## 1) Importación de librerías

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import statsmodels.formula.api as smf
import pysal as ps
import re
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# Out:
# E:\Miniconda3\envs\ds37\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# #### Importamos los datos y generamos el dataframe

# %%
df = pd.read_csv("properatti.csv")
df
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 0                0      sell            PH        Mataderos
# 1                1      sell     apartment         La Plata
# 2                2      sell     apartment        Mataderos
# 3                3      sell            PH          Liniers
# 4                4      sell     apartment           Centro
# ...            ...       ...           ...              ...
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121217      121217      sell     apartment    Villa Urquiza
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 3                     |Argentina|Capital Federal|Liniers|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...                                                   ...          ...
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 0                    Capital Federal    3430787.0
# 1             Bs.As. G.B.A. Zona Sur    3432039.0
# 2                    Capital Federal    3430787.0
# 3                    Capital Federal    3431333.0
# 4       Buenos Aires Costa Atlántica    3435548.0
# ...                              ...          ...
# 121215               Capital Federal    3436077.0
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
# 121219               Capital Federal    3433955.0
#
#                               lat-lon        lat  ...  surface_covered_in_m2  \
# 0             -34.6618237,-58.5088387 -34.661824  ...                   40.0
# 1             -34.9038831,-57.9643295 -34.903883  ...                    NaN
# 2             -34.6522615,-58.5229825 -34.652262  ...                   55.0
# 3             -34.6477969,-58.5164244 -34.647797  ...                    NaN
# 4             -38.0026256,-57.5494468 -38.002626  ...                   35.0
# ...                               ...        ...  ...                    ...
# 121215                            NaN        NaN  ...                   93.0
# 121216                            NaN        NaN  ...                  360.0
# 121217  -34.5706388726,-58.4755963355 -34.570639  ...                   39.0
# 121218                            NaN        NaN  ...                   48.0
# 121219                            NaN        NaN  ...                   77.0
#
#         price_usd_per_m2 price_per_m2  floor  rooms  expenses  \
# 0            1127.272727  1550.000000    NaN    NaN       NaN
# 1                    NaN          NaN    NaN    NaN       NaN
# 2            1309.090909  1309.090909    NaN    NaN       NaN
# 3                    NaN          NaN    NaN    NaN       NaN
# 4            1828.571429  1828.571429    NaN    NaN       NaN
# ...                  ...          ...    ...    ...       ...
# 121215       7699.115044  9354.838710    NaN    NaN   10000.0
# 121216       1383.333333  1383.333333    NaN    NaN       NaN
# 121217       2858.695652  3371.794872    NaN    NaN       NaN
# 121218       1997.916667  1997.916667    NaN    NaN       NaN
# 121219       1675.324675  1675.324675    NaN    NaN    3500.0
#
#                                             properati_url  \
# 0       http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1       http://www.properati.com.ar/15bob_venta_depart...
# 2       http://www.properati.com.ar/15bod_venta_depart...
# 3       http://www.properati.com.ar/15boh_venta_ph_lin...
# 4       http://www.properati.com.ar/15bok_venta_depart...
# ...                                                   ...
# 121215  http://www.properati.com.ar/1cja2_venta_depart...
# 121216  http://www.properati.com.ar/1cja6_venta_casa_b...
# 121217  http://www.properati.com.ar/1cja7_venta_depart...
# 121218  http://www.properati.com.ar/1cja8_venta_depart...
# 121219  http://www.properati.com.ar/1cjaa_venta_depart...
#
#                                               description  \
# 0       2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1       Venta de departamento en décimo piso al frente...
# 2       2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3       PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4       DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# ...                                                   ...
# 121215  TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...
# 121216  Excelente e impecable casa en Venta en Las Lom...
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218  2 Amb al contrafrente,  luminoso. El departame...
# 121219  Departamento de 77 m2 apto profesional. Edific...
#
#                                                     title  \
# 0                      2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1       VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2                2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                            PH 3 amb. cfte. reciclado
# 4       DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# ...                                                   ...
# 121215         Torre Forum Alcorta- Impecable 3 ambientes
# 121216  Ruca Inmuebles | Venta | Lomas de San Isidro |...
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218  2 amb. C/ dep. de servicio al contrafrente| Re...
# 121219         Departamento apto profesional en el Centro
#
#                                           image_thumbnail
# 0       https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1       https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2       https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
# 3       https://thumbs4.properati.com/3/DgIfX-85Mog5SP...
# 4       https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...
# ...                                                   ...
# 121215  https://thumbs4.properati.com/1/bjms0KnaAnlNoQ...
# 121216  https://thumbs4.properati.com/2/PCc3WuQDjpNZc4...
# 121217  https://thumbs4.properati.com/9/YAe_-2gRVykADP...
# 121218  https://thumbs4.properati.com/8/Q12PTvU6BQJ0ib...
# 121219  https://thumbs4.properati.com/8/mNEsnQWqB7joBF...
#
# [121220 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121220 entries, 0 to 121219
# Data columns (total 26 columns):
# Unnamed: 0                    121220 non-null int64
# operation                     121220 non-null object
# property_type                 121220 non-null object
# place_name                    121197 non-null object
# place_with_parent_names       121220 non-null object
# country_name                  121220 non-null object
# state_name                    121220 non-null object
# geonames_id                   102503 non-null float64
# lat-lon                       69670 non-null object
# lat                           69670 non-null float64
# lon                           69670 non-null float64
# price                         100810 non-null float64
# currency                      100809 non-null object
# price_aprox_local_currency    100810 non-null float64
# price_aprox_usd               100810 non-null float64
# surface_total_in_m2           81892 non-null float64
# surface_covered_in_m2         101313 non-null float64
# price_usd_per_m2              68617 non-null float64
# price_per_m2                  87658 non-null float64
# floor                         7899 non-null float64
# rooms                         47390 non-null float64
# expenses                      14262 non-null float64
# properati_url                 121220 non-null object
# description                   121218 non-null object
# title                         121220 non-null object
# image_thumbnail               118108 non-null object
# dtypes: float64(13), int64(1), object(12)
# memory usage: 24.0+ MB

# %%
place_split = df.place_with_parent_names.str.split('|', expand=True).rename({1:'pais', 2:'provincia',
                                                               3:'localidad', 4:'barrio'}, axis=1).drop([0,5,6], axis=1)

place_split.loc[(place_split.barrio == ''), 'barrio'] = np.nan

# %%
df = df.join(place_split)
# Out:
#         Unnamed: 0 operation property_type                place_name  \
# 92084        92084      sell     apartment  Bs.As. G.B.A. Zona Norte
# 82157        82157      sell         house               La Pilarica
# 96454        96454      sell     apartment                San Isidro
# 23267        23267      sell     apartment                  Saavedra
# 42718        42718      sell     apartment                    Flores
# 112173      112173      sell     apartment                   Rosario
# 39719        39719      sell     apartment             Mar del Plata
# 110497      110497      sell            PH                  Saavedra
# 17752        17752      sell     apartment              Constitución
# 52404        52404      sell            PH                  Belgrano
#
#                                   place_with_parent_names country_name  \
# 92084                |Argentina|Bs.As. G.B.A. Zona Norte|    Argentina
# 82157   |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|La P...    Argentina
# 96454   |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 23267                |Argentina|Capital Federal|Saavedra|    Argentina
# 42718                  |Argentina|Capital Federal|Flores|    Argentina
# 112173                       |Argentina|Santa Fe|Rosario|    Argentina
# 39719   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 110497               |Argentina|Capital Federal|Saavedra|    Argentina
# 17752            |Argentina|Capital Federal|Constitución|    Argentina
# 52404                |Argentina|Capital Federal|Belgrano|    Argentina
#
#                           state_name  geonames_id  \
# 92084       Bs.As. G.B.A. Zona Norte    3435907.0
# 82157       Bs.As. G.B.A. Zona Norte          NaN
# 96454       Bs.As. G.B.A. Zona Norte    3428983.0
# 23267                Capital Federal    3429422.0
# 42718                Capital Federal    3433918.0
# 112173                      Santa Fe    3838574.0
# 39719   Buenos Aires Costa Atlántica    3430863.0
# 110497               Capital Federal    3429422.0
# 17752                Capital Federal    3435257.0
# 52404                Capital Federal    3436077.0
#
#                               lat-lon        lat  ...  rooms  expenses  \
# 92084                             NaN        NaN  ...    NaN       NaN
# 82157                             NaN        NaN  ...    NaN    2500.0
# 96454                             NaN        NaN  ...    NaN       1.0
# 23267   -34.5503476609,-58.4833215911 -34.550348  ...    NaN       NaN
# 42718         -34.6282158,-58.4738734 -34.628216  ...    NaN       NaN
# 112173                            NaN        NaN  ...    NaN       NaN
# 39719         -38.0078135,-57.5607011 -38.007813  ...    2.0    1500.0
# 110497        -34.5447763,-58.4850897 -34.544776  ...    2.0       NaN
# 17752         -34.6295087,-58.3842218 -34.629509  ...    2.0       NaN
# 52404           -34.556883,-58.454218 -34.556883  ...    5.0       NaN
#
#                                             properati_url  \
# 92084   http://www.properati.com.ar/1bcel_venta_depart...
# 82157   http://www.properati.com.ar/1ayue_venta_casa_l...
# 96454   http://www.properati.com.ar/1biop_venta_depart...
# 23267   http://www.properati.com.ar/17l5w_venta_depart...
# 42718   http://www.properati.com.ar/18x0s_venta_depart...
# 112173  http://www.properati.com.ar/1c6md_venta_depart...
# 39719   http://www.properati.com.ar/18p50_venta_depart...
# 110497  http://www.properati.com.ar/1c4bh_venta_ph_saa...
# 17752   http://www.properati.com.ar/172sm_venta_depart...
# 52404   http://www.properati.com.ar/19j27_venta_ph_bel...
#
#                                               description  \
# 92084   Departamento en Campana centro, a pocas cuadra...
# 82157   exc casa 3 años hall amplio living comedor coc...
# 96454   Unidad de 3 dormitorios con gran balcon terraz...
# 23267   IMPECABLE DEPARTAMENTO DE 2 AMBIENTES AL FRENT...
# 42718   CODIGO: 2905-sch 06 ubicado en: helguera 300 -...
# 112173  Departamento al frente con balcon. Living come...
# 39719   Venta de Departamento 2 AMBIENTES, Mar del Pla...
# 110497  SAAVEDRA  P.H. al Frente  a EstrenarDos Grande...
# 17752   Depto. 2 amb. Amplio dormitorio. Cómodo.  Apto...
# 52404   Corredor Responsable: Raul Hector Merlo - CUCI...
#
#                                                     title  \
# 92084   Departamento 2 dormitorios en Venta en Campana...
# 82157                    venta de casa barrio la pilarica
# 96454         Venta Departamento 2 dormitorios San Isidro
# 23267   Departamento 79m² con Plantas en Besares 3700,...
# 42718                excelente depto con balcon y baulera
# 112173                       Departamento en Centro Oeste
# 39719                               DEPARTAMENTO EN VENTA
# 110497  SAAVEDRA PH A ESTRENAR 2 AMB AL FRENTE CON  BA...
# 17752                               PH 2 amb por escalera
# 52404   PH EN VENTA BELGRANO sin exp!!! 3 DE FEBRERO 2300
#
#                                           image_thumbnail       pais  \
# 92084   https://thumbs4.properati.com/2/zGXBHCCx1XKySi...  Argentina
# 82157   https://thumbs4.properati.com/0/MMTIHU6g_M1j4x...  Argentina
# 96454   https://thumbs4.properati.com/1/LqkPxdSp0SF0LP...  Argentina
# 23267   https://thumbs4.properati.com/8/7XNlfc9xBxgrNw...  Argentina
# 42718   https://thumbs4.properati.com/2/DDqc1obSRq52uu...  Argentina
# 112173  https://thumbs4.properati.com/2/Zl85Qb_GkFmGRZ...  Argentina
# 39719   https://thumbs4.properati.com/8/fw7buTV5MWY-aY...  Argentina
# 110497  https://thumbs4.properati.com/0/Ei09RSkRMXfqvv...  Argentina
# 17752   https://thumbs4.properati.com/6/T-7vnXGxviu_qh...  Argentina
# 52404   https://thumbs4.properati.com/5/SV6hfcG5AN32-F...  Argentina
#
#                            provincia      localidad       barrio
# 92084       Bs.As. G.B.A. Zona Norte                        None
# 82157       Bs.As. G.B.A. Zona Norte          Pilar  La Pilarica
# 96454       Bs.As. G.B.A. Zona Norte     San Isidro   San Isidro
# 23267                Capital Federal       Saavedra          NaN
# 42718                Capital Federal         Flores          NaN
# 112173                      Santa Fe        Rosario          NaN
# 39719   Buenos Aires Costa Atlántica  Mar del Plata          NaN
# 110497               Capital Federal       Saavedra          NaN
# 17752                Capital Federal   Constitución          NaN
# 52404                Capital Federal       Belgrano          NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# Este código hace exactamente lo mismo y sería la forma más limpia de hacerlo
# ```python
# df.place_with_parent_names.str.split('|', expand=True).rename({1:'pais', 2:'provincia',
#                                                                3:'partido', 4:'localidad',
#                                                                5:'barrio', 6:'zona'}, axis=1).drop(0, axis=1)
# #Alternativa
# place_split = df.place_with_parent_names.apply(lambda x: x.split('|')).apply(pd.Series)\
#                             .rename({1:'pais', 2:'provincia', 3:'partido', 4:'localidad',5:'barrio', 6:'zona'}, axis=1)\
#                             .drop(0, axis=1)
# ```

# %%
df.drop(["place_with_parent_names", "Unnamed: 0"], axis=1, inplace=True)

# %%
lat_lon = df['lat-lon'].str.split(',', expand=True)
lat_lon = lat_lon.rename({0:'lat', 1:'lon'}, axis=1)
df = df.drop(['lat-lon', 'lat', 'lon'], axis=1).join(lat_lon)

# %%
df['lat'] = df.lat.astype(np.float)
df['lon'] = df.lon.astype(np.float)

# %%
pattern = []
df.head(10).description[0]
# Out:
# '2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO, REFACCIONADO A NUEVO, PATIO GRANDE, CON LAVADERO, LIVING COMEDOR CON COCINA INTEGRADA, ARTEFACTO DE COCINA, ALACENA, BAÑO COMPLETO, Y DORMITORIO. TODO EN EXCELENTE ESTADO, PARA HABITAR.NO ES APTO CREDITO Aviso publicado por Pixel Inmobiliario (Servicio de Páginas Web para Inmobiliarias).'

# %%
pattern_usd = r'[u$s dolares]?((?!\()\d{1,3}[,.]\d{1,3}[,.]?\d{3}?(?!\)))|((?!\()\d{1,3}[,.]\d{3}(?!\)))|((?!\()\d{5,}(?!\)))'
pat_tag_usd = r'(usd|u\$s|us\$|dolares|dólares|us)'
pat_tag_ars = r''

# %%
pat_ambientes = r'\b(\d{1,2})\s*amb'
pat_dormitorios = r'\b(\d{1,2})\s*dor'

# %%
df['ambientes'] = df.title.str.extract(pat_ambientes, re.IGNORECASE, expand=True)
df['dormitorios'] = df.title.str.extract(pat_dormitorios, re.IGNORECASE, expand=True)

# %%
df.loc[~(df.ambientes.isnull())].filter(['ambientes']).ambientes.unique()
# Out:
# array(['2', '3', '4', '6', '1', '5', '7', '9', '8', '15', '10', '11',
#        '12', '14'], dtype=object)

# %%
df.loc[(ambientes==14)].filter(['ambientes'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-f2d65316b68f> in <module>
# ----> 1 df.loc[(ambientes==14)].filter(['ambientes'])
#
# NameError: name 'ambientes' is not defined

# %%
a = df.filter(['ambientes', 'dormitorios', 'rooms']).loc[~(df.rooms.isnull()) &\
                                                         ~(df.ambientes.isnull())].ambientes.astype(np.float64)\
    == df.filter(['ambientes', 'dormitorios', 'rooms']).loc[~(df.rooms.isnull()) & ~(df.ambientes.isnull())].rooms

# %%
a.sum()/len(a)
# Out:
# 0.9498057734785589

# %% [markdown]
# El resultado anterior indica que rooms y ambientes es lo mismo, por lo que podemos rellenar los `NaN` de *'rooms'* con *'ambientes'*

# %%
df.loc[~(df.dormitorios.isnull())].filter(['description', 'dormitorios'])
# Out:
#                                               description dormitorios
# 1       Venta de departamento en décimo piso al frente...           2
# 9       MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...           2
# 34      Amplio PH de 5 dormitorios, ubicado a 3 cuadra...           5
# 73      SE VENDE CASA EN EL MICROCENTRO DE 150 mts2 CO...           2
# 83      IDEAL INVERSORES o ESTUDIANTES APTA CREDITO An...           2
# ...                                                   ...         ...
# 120331  Gran departamento en venta de 3 dormitoriosDep...           3
# 120962  Hermosa Casa sobre gran lote en esquina muy lu...           4
# 120966  HDH Propiedades presenta  a la venta casa apta...           3
# 121101  Excelente casa de dos plantas a entrenar en Sa...           3
# 121144  OLSEN PROPIEDADES TIENE EL AGRADO DE PRESENTAR...           3
#
# [7764 rows x 2 columns]

# %%
#df.rooms.fillna(df.ambientes, inplace=True)
#df.filter(['rooms', 'ambientes', 'dormitorios']).loc[~(df.rooms.isnull())]

# %%
df['re_usd'] = df.title.str.extract(pat_tag_usd, re.IGNORECASE)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'ambientes', 'dormitorios', 're_usd'],
#       dtype='object')

# %%
df.loc[~(df.re_usd.isnull())&(df.price.isnull())].filter(['re_usd']).values
# Out:
# array([['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['Us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['U$S'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['U$S'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['U$S'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['USD'],
#        ['us'],
#        ['us'],
#        ['U$S'],
#        ['U$S'],
#        ['U$S'],
#        ['U$S'],
#        ['Us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['u$s'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['U$S'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['u$s'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['us'],
#        ['us'],
#        ['US'],
#        ['US'],
#        ['US'],
#        ['us'],
#        ['us']], dtype=object)

# %%
df.iloc[8]['title']
# Out:
# 'JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR , CATEGORIA , VENTA'

# %%
df['amb_description'] = df.description.str.extract(pat_ambientes, re.IGNORECASE, expand=True)

# %%
#df.rooms.fillna(df.amb_description, inplace=True)

# %%
df.loc[~(df.rooms.isnull())].rooms.shape
# Out:
# (47390,)

# %%
pat_amb_esp = r'ambientes:([\s]?\d{1,2})'

# %%
df['amb_des_es'] = df.description.str.extract(pat_amb_esp, re.IGNORECASE, expand=True)

# %%
df.loc[~(df.amb_des_es.isnull())].sample(1).filter(['description']).values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-70b418a76f6e> in <module>
# ----> 1 df.loc[~(df.amb_des_es.isnull())].sample(1).filter(['description']).values
#
# E:\Miniconda3\envs\ds37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'amb_des_es'

# %%
b = df.loc[~(df.rooms.isnull()) &\
                                                         ~(df.amb_des_es.isnull())].amb_des_es.astype(np.float64)\
    == df.loc[~(df.rooms.isnull()) & ~(df.amb_des_es.isnull())].rooms

# %%
b.sum()/b.count()
# Out:
# 0.4626865671641791
