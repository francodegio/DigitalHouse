# %% [markdown]
# # Valor real de los inmuebles: optimización de recursos provinciales desde un paradigma progresivo.

# %% [markdown]
# ## 1. Tareas Preliminares
# ### I. Importación de librerías

# %%
import pandas as pd
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
import os
import folium
import pysal
import geopandas as gpd
# %matplotlib inline

# %% [markdown]
# ### II. Importación de datos

# %%
df = pd.read_excel("datos_tesis.xls")
df
# Out:
#          Price   PriceUS  LotLandSize  ConstructionSize  Bedrooms  Bathrooms  \
# 0    1700000.0       NaN        420.0             60.00       2.0        1.0
# 1    4350000.0       NaN        500.0            151.00       3.0        2.0
# 2    3000000.0       NaN        270.0             61.32       2.0        1.0
# 3          NaN   75000.0        200.0             80.00       2.0        1.0
# 4    4000000.0       NaN        249.0            146.00       2.0        2.0
# 5    3600000.0       NaN        400.0             70.00       2.0        1.0
# 6          NaN  260000.0        371.0            304.00       5.0        2.0
# 7          NaN  210000.0        400.0            180.00       3.0        2.0
# 8          NaN  160000.0        370.0            110.00       2.0        1.0
# 9    4000000.0       NaN        350.0            200.00       3.0        2.0
# 10   1500000.0       NaN        300.0             70.00       3.0        1.0
# 11   3500000.0       NaN        200.0            115.00       3.0        1.0
# 12         NaN     650.0        300.0            170.00       3.0        2.0
# 13   2400000.0       NaN        197.0            135.00       3.0        2.0
# 14   5800000.0       NaN         40.0            150.00       3.0        2.0
# 15         NaN  240000.0        450.0            120.00       3.0        2.0
# 16         NaN  145000.0        380.0            145.00       3.0        2.0
# 17   5200000.0       NaN        527.0            235.00       5.0        3.0
# 18         NaN  120000.0        650.0            195.00       2.0        2.0
# 19         NaN  130000.0        650.0            210.00       3.0        2.0
# 20         NaN  120000.0        422.0            247.00       3.0        3.0
# 21         NaN  118000.0        400.0            235.00       2.0        2.0
# 22   5600000.0       NaN        234.0            234.00       3.0        4.0
# 23   2300000.0       NaN        332.0             72.00       2.0        1.0
# 24   2850000.0       NaN        250.0            135.00       3.0        1.0
# 25   3950000.0       NaN        250.0            150.00       3.0        2.0
# 26   3225000.0       NaN       1273.0            215.00       3.0        2.0
# 27   4300000.0       NaN        265.0            131.52       3.0        2.0
# 28         NaN  216000.0       1403.0            320.00       3.0        4.0
# 29         NaN  130000.0        770.0            120.00       2.0        1.0
# ..         ...       ...          ...               ...       ...        ...
# 864        NaN   16000.0        880.0               NaN       NaN        NaN
# 865   400000.0       NaN        403.0               NaN       NaN        NaN
# 866   450000.0       NaN       2000.0               NaN       NaN        NaN
# 867   730000.0       NaN        320.0               NaN       NaN        NaN
# 868   700000.0       NaN        181.5               NaN       NaN        NaN
# 869   800000.0       NaN        775.0               NaN       NaN        NaN
# 870   450000.0       NaN       1500.0               NaN       NaN        NaN
# 871   500000.0       NaN       1200.0               NaN       NaN        NaN
# 872        NaN      80.0        431.0               NaN       NaN        NaN
# 873   320000.0       NaN        321.5               NaN       NaN        NaN
# 874   980000.0       NaN       6800.0               NaN       NaN        NaN
# 875   120000.0       NaN        328.0               NaN       NaN        NaN
# 876   450000.0       NaN       1800.0               NaN       NaN        NaN
# 877   650000.0       NaN       1000.0               NaN       NaN        NaN
# 878   380000.0       NaN        475.0               NaN       NaN        NaN
# 879        NaN  550000.0       9000.0               NaN       NaN        NaN
# 880   450000.0       NaN        213.0               NaN       NaN        NaN
# 881        NaN   25000.0        986.0               NaN       NaN        NaN
# 882  2100000.0       NaN       2700.0               NaN       NaN        NaN
# 883   630000.0       NaN        800.0               NaN       NaN        NaN
# 884   750000.0       NaN        820.0               NaN       NaN        NaN
# 885   450000.0       NaN       1500.0               NaN       NaN        NaN
# 886   600000.0       NaN        800.0               NaN       NaN        NaN
# 887   380000.0       NaN        350.0               NaN       NaN        NaN
# 888  1200000.0       NaN       1500.0               NaN       NaN        NaN
# 889  2800000.0       NaN        480.0               NaN       NaN        NaN
# 890        NaN   20000.0        250.0               NaN       NaN        NaN
# 891   100000.0       NaN        300.0               NaN       NaN        NaN
# 892   180000.0       NaN        300.0               NaN       NaN        NaN
# 893   850000.0       NaN       5700.0               NaN       NaN        NaN
#
#      CarParkingLots     District   Latitude  Longitude PropertyType
# 0               1.0  Santa Lucia -31.536921 -68.451610        Casas
# 1               3.0      Capital -31.523386 -68.529153        Casas
# 2               1.0       Rawson -31.586140 -68.515935        Casas
# 3               1.0    Rivadavia -31.520605 -68.591981        Casas
# 4               1.0      Capital -31.521341 -68.558553        Casas
# 5               1.0    Rivadavia -31.515228 -68.594105        Casas
# 6               2.0      Capital -31.534177 -68.526492        Casas
# 7               1.0  Santa Lucia -31.542187 -68.503189        Casas
# 8               2.0    Rivadavia -31.550361 -68.565824        Casas
# 9               2.0      Capital -31.538496 -68.522870        Casas
# 10              1.0      Chimbas -31.499979 -68.560717        Casas
# 11              0.0    Rivadavia -31.525338 -68.590278        Casas
# 12              1.0    Rivadavia -31.528603 -68.587496        Casas
# 13              0.0      Capital -31.545680 -68.542714        Casas
# 14              2.0  Santa Lucia -31.539151 -68.490529        Casas
# 15              1.0  Santa Lucia -31.528635 -68.482482        Casas
# 16              1.0      Capital -31.527776 -68.520141        Casas
# 17              1.0      Capital -31.521922 -68.512352        Casas
# 18              2.0    Rivadavia -31.519947 -68.606915        Casas
# 19              2.0    Rivadavia -31.519984 -68.606615        Casas
# 20              1.0      Capital -31.552985 -68.536052        Casas
# 21              0.0  Santa Lucia -31.544199 -68.488512        Casas
# 22              2.0      Capital -31.534872 -68.513961        Casas
# 23              1.0       Rawson -31.587017 -68.502631        Casas
# 24              2.0      Capital -31.527446 -68.518596        Casas
# 25              1.0      Capital -31.514386 -68.551211        Casas
# 26              1.0       Rawson -31.601529 -68.484049        Casas
# 27              1.0      Capital -31.546411 -68.559612        Casas
# 28              1.0  Santa Lucia -31.539334 -68.467205        Casas
# 29              1.0  Santa Lucia -31.547810 -68.477590        Casas
# ..              ...          ...        ...        ...          ...
# 864             NaN  Santa Lucia -31.533482 -68.462119        Lotes
# 865             NaN       Rawson -31.557347 -68.571534        Lotes
# 866             NaN       Rawson -31.612677 -68.485293        Lotes
# 867             NaN    Rivadavia -31.552583 -68.569649        Lotes
# 868             NaN    Rivadavia -31.542809 -68.586831        Lotes
# 869             NaN  Santa Lucia -31.521483 -68.477569        Lotes
# 870             NaN       Rawson -31.584346 -68.478365        Lotes
# 871             NaN  Santa Lucia -31.540420 -68.453247        Lotes
# 872             NaN       Rawson -31.562009 -68.512716        Lotes
# 873             NaN  Santa Lucia -31.502715 -68.477654        Lotes
# 874             NaN       Rawson -31.610265 -68.489714        Lotes
# 875             NaN      Chimbas -31.493054 -68.555621        Lotes
# 876             NaN       Rawson -31.614650 -68.467956        Lotes
# 877             NaN  Santa Lucia -31.562828 -68.455265        Lotes
# 878             NaN    Rivadavia -31.517069 -68.515733        Lotes
# 879             NaN    Rivadavia -31.522325 -68.581692        Lotes
# 880             NaN       Rawson -31.560180 -68.505528        Lotes
# 881             NaN       Rawson -31.554841 -68.591380        Lotes
# 882             NaN      Capital -31.513239 -68.537655        Lotes
# 883             NaN  Santa Lucia -31.552866 -68.505893        Lotes
# 884             NaN       Rawson -31.549136 -68.593097        Lotes
# 885             NaN       Rawson -31.582987 -68.478441        Lotes
# 886             NaN  Santa Lucia -31.529312 -68.460574        Lotes
# 887             NaN       Rawson -31.576342 -68.579793        Lotes
# 888             NaN       Rawson -31.570028 -68.512917        Lotes
# 889             NaN  Santa Lucia -31.526056 -68.463278        Lotes
# 890             NaN       Pocito -31.651263 -68.578506        Lotes
# 891             NaN       Rawson -31.534150 -68.523472        Lotes
# 892             NaN       Pocito -31.589823 -68.559510        Lotes
# 893             NaN       Pocito -31.586176 -68.580265        Lotes
#
# [894 rows x 11 columns]

# %%
df.tail()
# Out:
#          Price  PriceUS  LotLandSize  ConstructionSize  Bedrooms  Bathrooms  \
# 889  2800000.0      NaN        480.0               NaN       NaN        NaN
# 890        NaN  20000.0        250.0               NaN       NaN        NaN
# 891   100000.0      NaN        300.0               NaN       NaN        NaN
# 892   180000.0      NaN        300.0               NaN       NaN        NaN
# 893   850000.0      NaN       5700.0               NaN       NaN        NaN
#
#      CarParkingLots     District   Latitude  Longitude PropertyType
# 889             NaN  Santa Lucia -31.526056 -68.463278        Lotes
# 890             NaN       Pocito -31.651263 -68.578506        Lotes
# 891             NaN       Rawson -31.534150 -68.523472        Lotes
# 892             NaN       Pocito -31.589823 -68.559510        Lotes
# 893             NaN       Pocito -31.586176 -68.580265        Lotes

# %% [markdown]
# ## III. Construimos las variables necesarias

# %%
# convertimos las variables en floats
df['bsqm'] = df['ConstructionSize'].astype(np.float64, errors='ignore')
df['lat'] = df['Latitude'].astype(np.float64)
df['long'] = df['Longitude'].astype(np.float64)


# generacion de variables dummies segun tipo de inmueble
df['house'] = 0
df['lot'] = 0
df['dept'] = 0
df.loc[(df.PropertyType=="Casas"), 'house'] = 1
df.loc[(df.PropertyType=="Lotes"), 'lot'] = 1
df.loc[(df.PropertyType=="Departamentos"), 'dept'] = 1

df['type'] = df['PropertyType']

# generacion de variables dummies segun distrito (departamento)
df['dcap'] = 0 # capital
df['dsta'] = 0 # santa lucia
df['driv'] = 0 # rivadavia
df['draw'] = 0 # rawson
df['dchi'] = 0 # chimbas
df['dpoc'] = 0 # pocito

df.loc[(df.District=="Capital"), 'dcap'] = 1
df.loc[(df.District=="Santa Lucia"), 'dsta'] = 1
df.loc[(df.District=="Rivadavia"), 'driv'] = 1
df.loc[(df.District=="Rawson"), 'draw'] = 1
df.loc[(df.District=="Pocito"), 'dpoc'] = 1
df.loc[(df.District=="Chimbas"), 'dchi'] = 1

# reemplazo de valores erroneos
#df.loc[(df.Bedrooms=='NaN'), 'Bedrooms'] = 0
#df.loc[(df.Bathrooms=='NaN'), 'Bathrooms'] = 0
#df.loc[(df.CarParkingLots=='NaN'), 'CarParkingLots'] = 0

df['Bedrooms'] = df['Bedrooms'].astype(np.float64, errors='ignore')
df['Bathrooms'] = df['Bathrooms'].astype(np.float64, errors='ignore')
df['CarParkingLots'] = df['CarParkingLots'].astype(np.float64, errors='ignore')


# generacion de variables dummies segun cantidad de banos
df['baths'] = df['Bathrooms']
df['bath1'] = 0
df['bath2'] = 0
df['bath3'] = 0
df['bath4'] = 0
df['bath5'] = 0
df.loc[(df.Bathrooms==1), 'bath1'] = 1
df.loc[(df.Bathrooms==2), 'bath2'] = 1
df.loc[(df.Bathrooms==3), 'bath3'] = 1
df.loc[(df.Bathrooms==4), 'bath4'] = 1
df.loc[(df.Bathrooms==5), 'bath5'] = 1

# generacion de variables dummies segun cantidad de dormitorios
df['dorms'] = df['Bedrooms']
df['dorm1'] = 0
df['dorm2'] = 0
df['dorm3'] = 0
df['dorm4'] = 0
df['dorm5'] = 0
df.loc[(df.Bedrooms==1), 'dorm1'] = 1
df.loc[(df.Bedrooms==2), 'dorm2'] = 1
df.loc[(df.Bedrooms==3), 'dorm3'] = 1
df.loc[(df.Bedrooms==4), 'dorm4'] = 1
df.loc[(df.Bedrooms==5), 'dorm5'] = 1

# generacion de variables dummies segun cantidad de cocheras
df['garages'] = df['CarParkingLots']
df['garage1'] = 0
df['garage2'] = 0
df['garage3'] = 0
df['garage4'] = 0
df['garage5'] = 0
df.loc[(df.CarParkingLots==1), 'garage1'] = 1
df.loc[(df.CarParkingLots==2), 'garage2'] = 1
df.loc[(df.CarParkingLots==3), 'garage3'] = 1
df.loc[(df.CarParkingLots==4), 'garage4'] = 1
df.loc[(df.CarParkingLots==5), 'garage5'] = 1

# precios en pesos y unificados
USDxARS = 43

df['PriceArs'] = df['Price']
df['PriceArs'] = df['PriceArs'].fillna(df.PriceUS*USDxARS)

# unificacion m2
df['tsqm'] = df['LotLandSize']

# forzamos variables a float
df['tsqm'] = pd.to_numeric(df.tsqm, errors='coerce').astype(np.float64, errors='ignore')
df['bsqm'] = pd.to_numeric(df.bsqm, errors='coerce').astype(np.float64, errors='ignore')

# Calculamos el cuadrado de estas variables
df['tsqm2'] = df['tsqm'].apply(np.square)
df['bsqm2'] = df['bsqm'].apply(np.square)


# logaritmo natural del precios
#df['p'] = df['PriceArs']
#df['lp'] = df['p'].apply(np.log)
df['lprice'] = df['PriceArs'].apply(np.log)

# ratio de metros construidos
df['b_ratio'] = df['bsqm']/df['tsqm']

df['pm2'] = df['PriceArs']/df['tsqm']

# %% [markdown]
# ## IV. Filtramos el dataframe a las variables homogeneizadas que nos interesan

# %%
df = df.filter(['PriceArs','lprice', 'tsqm', 'tsqm2', 'bsqm', 'bsqm2', 'house', 'dept', 'lot', 'lat', 'long',
                'bath1', 'bath2', 'bath3', 'bath4', 'bath5', 'garages', 'garage1', 'garage2', 'garage3',
                'garage4', 'garage5', 'dorm1', 'dorm2', 'dorm3', 'dorm4', 'dorm5', 'mratio', 'baths', 'dorms', 'p', 'lp',
                'type', 'dcap', 'dsta', 'driv', 'draw', 'dpoc', 'dchi', 'pm2', 'b_ratio', 'District'])

df
# Out:
#        PriceArs     lprice    tsqm        tsqm2    bsqm        bsqm2  house  \
# 0     1700000.0  14.346139   420.0    176400.00   60.00    3600.0000      1
# 1     4350000.0  15.285686   500.0    250000.00  151.00   22801.0000      1
# 2     3000000.0  14.914123   270.0     72900.00   61.32    3760.1424      1
# 3     3225000.0  14.986444   200.0     40000.00   80.00    6400.0000      1
# 4     4000000.0  15.201805   249.0     62001.00  146.00   21316.0000      1
# 5     3600000.0  15.096444   400.0    160000.00   70.00    4900.0000      1
# 6    11180000.0  16.229637   371.0    137641.00  304.00   92416.0000      1
# 7     9030000.0  16.016063   400.0    160000.00  180.00   32400.0000      1
# 8     6880000.0  15.744129   370.0    136900.00  110.00   12100.0000      1
# 9     4000000.0  15.201805   350.0    122500.00  200.00   40000.0000      1
# 10    1500000.0  14.220976   300.0     90000.00   70.00    4900.0000      1
# 11    3500000.0  15.068274   200.0     40000.00  115.00   13225.0000      1
# 12      27950.0  10.238172   300.0     90000.00  170.00   28900.0000      1
# 13    2400000.0  14.690979   197.0     38809.00  135.00   18225.0000      1
# 14    5800000.0  15.573368    40.0      1600.00  150.00   22500.0000      1
# 15   10320000.0  16.149594   450.0    202500.00  120.00   14400.0000      1
# 16    6235000.0  15.645689   380.0    144400.00  145.00   21025.0000      1
# 17    5200000.0  15.464169   527.0    277729.00  235.00   55225.0000      1
# 18    5160000.0  15.456447   650.0    422500.00  195.00   38025.0000      1
# 19    5590000.0  15.536490   650.0    422500.00  210.00   44100.0000      1
# 20    5160000.0  15.456447   422.0    178084.00  247.00   61009.0000      1
# 21    5074000.0  15.439640   400.0    160000.00  235.00   55225.0000      1
# 22    5600000.0  15.538277   234.0     54756.00  234.00   54756.0000      1
# 23    2300000.0  14.648420   332.0    110224.00   72.00    5184.0000      1
# 24    2850000.0  14.862830   250.0     62500.00  135.00   18225.0000      1
# 25    3950000.0  15.189226   250.0     62500.00  150.00   22500.0000      1
# 26    3225000.0  14.986444  1273.0   1620529.00  215.00   46225.0000      1
# 27    4300000.0  15.274126   265.0     70225.00  131.52   17297.5104      1
# 28    9288000.0  16.044234  1403.0   1968409.00  320.00  102400.0000      1
# 29    5590000.0  15.536490   770.0    592900.00  120.00   14400.0000      1
# ..          ...        ...     ...          ...     ...          ...    ...
# 864    688000.0  13.441544   880.0    774400.00     NaN          NaN      0
# 865    400000.0  12.899220   403.0    162409.00     NaN          NaN      0
# 866    450000.0  13.017003  2000.0   4000000.00     NaN          NaN      0
# 867    730000.0  13.500800   320.0    102400.00     NaN          NaN      0
# 868    700000.0  13.458836   181.5     32942.25     NaN          NaN      0
# 869    800000.0  13.592367   775.0    600625.00     NaN          NaN      0
# 870    450000.0  13.017003  1500.0   2250000.00     NaN          NaN      0
# 871    500000.0  13.122363  1200.0   1440000.00     NaN          NaN      0
# 872      3440.0   8.143227   431.0    185761.00     NaN          NaN      0
# 873    320000.0  12.676076   321.5    103362.25     NaN          NaN      0
# 874    980000.0  13.795308  6800.0  46240000.00     NaN          NaN      0
# 875    120000.0  11.695247   328.0    107584.00     NaN          NaN      0
# 876    450000.0  13.017003  1800.0   3240000.00     NaN          NaN      0
# 877    650000.0  13.384728  1000.0   1000000.00     NaN          NaN      0
# 878    380000.0  12.847927   475.0    225625.00     NaN          NaN      0
# 879  23650000.0  16.978874  9000.0  81000000.00     NaN          NaN      0
# 880    450000.0  13.017003   213.0     45369.00     NaN          NaN      0
# 881   1075000.0  13.887831   986.0    972196.00     NaN          NaN      0
# 882   2100000.0  14.557448  2700.0   7290000.00     NaN          NaN      0
# 883    630000.0  13.353475   800.0    640000.00     NaN          NaN      0
# 884    750000.0  13.527828   820.0    672400.00     NaN          NaN      0
# 885    450000.0  13.017003  1500.0   2250000.00     NaN          NaN      0
# 886    600000.0  13.304685   800.0    640000.00     NaN          NaN      0
# 887    380000.0  12.847927   350.0    122500.00     NaN          NaN      0
# 888   1200000.0  13.997832  1500.0   2250000.00     NaN          NaN      0
# 889   2800000.0  14.845130   480.0    230400.00     NaN          NaN      0
# 890    860000.0  13.664688   250.0     62500.00     NaN          NaN      0
# 891    100000.0  11.512925   300.0     90000.00     NaN          NaN      0
# 892    180000.0  12.100712   300.0     90000.00     NaN          NaN      0
# 893    850000.0  13.652992  5700.0  32490000.00     NaN          NaN      0
#
#      dept  lot        lat     ...        type  dcap  dsta  driv  draw  dpoc  \
# 0       0    0 -31.536921     ...       Casas     0     1     0     0     0
# 1       0    0 -31.523386     ...       Casas     1     0     0     0     0
# 2       0    0 -31.586140     ...       Casas     0     0     0     1     0
# 3       0    0 -31.520605     ...       Casas     0     0     1     0     0
# 4       0    0 -31.521341     ...       Casas     1     0     0     0     0
# 5       0    0 -31.515228     ...       Casas     0     0     1     0     0
# 6       0    0 -31.534177     ...       Casas     1     0     0     0     0
# 7       0    0 -31.542187     ...       Casas     0     1     0     0     0
# 8       0    0 -31.550361     ...       Casas     0     0     1     0     0
# 9       0    0 -31.538496     ...       Casas     1     0     0     0     0
# 10      0    0 -31.499979     ...       Casas     0     0     0     0     0
# 11      0    0 -31.525338     ...       Casas     0     0     1     0     0
# 12      0    0 -31.528603     ...       Casas     0     0     1     0     0
# 13      0    0 -31.545680     ...       Casas     1     0     0     0     0
# 14      0    0 -31.539151     ...       Casas     0     1     0     0     0
# 15      0    0 -31.528635     ...       Casas     0     1     0     0     0
# 16      0    0 -31.527776     ...       Casas     1     0     0     0     0
# 17      0    0 -31.521922     ...       Casas     1     0     0     0     0
# 18      0    0 -31.519947     ...       Casas     0     0     1     0     0
# 19      0    0 -31.519984     ...       Casas     0     0     1     0     0
# 20      0    0 -31.552985     ...       Casas     1     0     0     0     0
# 21      0    0 -31.544199     ...       Casas     0     1     0     0     0
# 22      0    0 -31.534872     ...       Casas     1     0     0     0     0
# 23      0    0 -31.587017     ...       Casas     0     0     0     1     0
# 24      0    0 -31.527446     ...       Casas     1     0     0     0     0
# 25      0    0 -31.514386     ...       Casas     1     0     0     0     0
# 26      0    0 -31.601529     ...       Casas     0     0     0     1     0
# 27      0    0 -31.546411     ...       Casas     1     0     0     0     0
# 28      0    0 -31.539334     ...       Casas     0     1     0     0     0
# 29      0    0 -31.547810     ...       Casas     0     1     0     0     0
# ..    ...  ...        ...     ...         ...   ...   ...   ...   ...   ...
# 864     0    1 -31.533482     ...       Lotes     0     1     0     0     0
# 865     0    1 -31.557347     ...       Lotes     0     0     0     1     0
# 866     0    1 -31.612677     ...       Lotes     0     0     0     1     0
# 867     0    1 -31.552583     ...       Lotes     0     0     1     0     0
# 868     0    1 -31.542809     ...       Lotes     0     0     1     0     0
# 869     0    1 -31.521483     ...       Lotes     0     1     0     0     0
# 870     0    1 -31.584346     ...       Lotes     0     0     0     1     0
# 871     0    1 -31.540420     ...       Lotes     0     1     0     0     0
# 872     0    1 -31.562009     ...       Lotes     0     0     0     1     0
# 873     0    1 -31.502715     ...       Lotes     0     1     0     0     0
# 874     0    1 -31.610265     ...       Lotes     0     0     0     1     0
# 875     0    1 -31.493054     ...       Lotes     0     0     0     0     0
# 876     0    1 -31.614650     ...       Lotes     0     0     0     1     0
# 877     0    1 -31.562828     ...       Lotes     0     1     0     0     0
# 878     0    1 -31.517069     ...       Lotes     0     0     1     0     0
# 879     0    1 -31.522325     ...       Lotes     0     0     1     0     0
# 880     0    1 -31.560180     ...       Lotes     0     0     0     1     0
# 881     0    1 -31.554841     ...       Lotes     0     0     0     1     0
# 882     0    1 -31.513239     ...       Lotes     1     0     0     0     0
# 883     0    1 -31.552866     ...       Lotes     0     1     0     0     0
# 884     0    1 -31.549136     ...       Lotes     0     0     0     1     0
# 885     0    1 -31.582987     ...       Lotes     0     0     0     1     0
# 886     0    1 -31.529312     ...       Lotes     0     1     0     0     0
# 887     0    1 -31.576342     ...       Lotes     0     0     0     1     0
# 888     0    1 -31.570028     ...       Lotes     0     0     0     1     0
# 889     0    1 -31.526056     ...       Lotes     0     1     0     0     0
# 890     0    1 -31.651263     ...       Lotes     0     0     0     0     1
# 891     0    1 -31.534150     ...       Lotes     0     0     0     1     0
# 892     0    1 -31.589823     ...       Lotes     0     0     0     0     1
# 893     0    1 -31.586176     ...       Lotes     0     0     0     0     1
#
#      dchi            pm2   b_ratio     District
# 0       0    4047.619048  0.142857  Santa Lucia
# 1       0    8700.000000  0.302000      Capital
# 2       0   11111.111111  0.227111       Rawson
# 3       0   16125.000000  0.400000    Rivadavia
# 4       0   16064.257028  0.586345      Capital
# 5       0    9000.000000  0.175000    Rivadavia
# 6       0   30134.770889  0.819407      Capital
# 7       0   22575.000000  0.450000  Santa Lucia
# 8       0   18594.594595  0.297297    Rivadavia
# 9       0   11428.571429  0.571429      Capital
# 10      1    5000.000000  0.233333      Chimbas
# 11      0   17500.000000  0.575000    Rivadavia
# 12      0      93.166667  0.566667    Rivadavia
# 13      0   12182.741117  0.685279      Capital
# 14      0  145000.000000  3.750000  Santa Lucia
# 15      0   22933.333333  0.266667  Santa Lucia
# 16      0   16407.894737  0.381579      Capital
# 17      0    9867.172676  0.445920      Capital
# 18      0    7938.461538  0.300000    Rivadavia
# 19      0    8600.000000  0.323077    Rivadavia
# 20      0   12227.488152  0.585308      Capital
# 21      0   12685.000000  0.587500  Santa Lucia
# 22      0   23931.623932  1.000000      Capital
# 23      0    6927.710843  0.216867       Rawson
# 24      0   11400.000000  0.540000      Capital
# 25      0   15800.000000  0.600000      Capital
# 26      0    2533.385703  0.168892       Rawson
# 27      0   16226.415094  0.496302      Capital
# 28      0    6620.099786  0.228083  Santa Lucia
# 29      0    7259.740260  0.155844  Santa Lucia
# ..    ...            ...       ...          ...
# 864     0     781.818182       NaN  Santa Lucia
# 865     0     992.555831       NaN       Rawson
# 866     0     225.000000       NaN       Rawson
# 867     0    2281.250000       NaN    Rivadavia
# 868     0    3856.749311       NaN    Rivadavia
# 869     0    1032.258065       NaN  Santa Lucia
# 870     0     300.000000       NaN       Rawson
# 871     0     416.666667       NaN  Santa Lucia
# 872     0       7.981439       NaN       Rawson
# 873     0     995.334370       NaN  Santa Lucia
# 874     0     144.117647       NaN       Rawson
# 875     1     365.853659       NaN      Chimbas
# 876     0     250.000000       NaN       Rawson
# 877     0     650.000000       NaN  Santa Lucia
# 878     0     800.000000       NaN    Rivadavia
# 879     0    2627.777778       NaN    Rivadavia
# 880     0    2112.676056       NaN       Rawson
# 881     0    1090.263692       NaN       Rawson
# 882     0     777.777778       NaN      Capital
# 883     0     787.500000       NaN  Santa Lucia
# 884     0     914.634146       NaN       Rawson
# 885     0     300.000000       NaN       Rawson
# 886     0     750.000000       NaN  Santa Lucia
# 887     0    1085.714286       NaN       Rawson
# 888     0     800.000000       NaN       Rawson
# 889     0    5833.333333       NaN  Santa Lucia
# 890     0    3440.000000       NaN       Pocito
# 891     0     333.333333       NaN       Rawson
# 892     0     600.000000       NaN       Pocito
# 893     0     149.122807       NaN       Pocito
#
# [894 rows x 39 columns]

# %% [markdown]
# ## 2. Análisis exploratorio de datos

# %%
sns.pairplot(df, vars=['PriceArs'], hue='type', height=7, markers='type' );
'Distribución de precios de los inmuebles: \
Casas en Azul, Departamentos en Naranja y Lotes en Verde'
# Out:
# 'Distribución de precios de los inmuebles: Casas en Azul, Departamentos en Naranja y Lotes en Verde'

# %%
sns.pairplot(df, vars=['lprice'], hue='type', height=7, markers='type' );
'Distribución del logaritmo de precios de los inmuebles: \
Casas en Azul, Departamentos en Naranja y Lotes en Verde'
# Out:
# 'Distribución del logaritmo de precios de los inmuebles: Casas en Azul, Departamentos en Naranja y Lotes en Verde'

# %%
sns.pairplot(df, vars=['pm2'], hue='type', height=7, markers='type' );
'Distribución del logaritmo de precios de los inmuebles: \
Casas en Azul, Departamentos en Naranja y Lotes en Verde'
# Out:
# 'Distribución del logaritmo de precios de los inmuebles: Casas en Azul, Departamentos en Naranja y Lotes en Verde'

# %%
df.pivot_table('pm2', columns='type', aggfunc=['mean', np.std])
# Out:
#               mean                                      std                \
# type         Casas Departamentos        Lotes         Casas Departamentos
# pm2   14273.012619  37964.350296  1770.243424  15113.614394  24120.567529
#
#
# type        Lotes
# pm2   2732.651577

# %% [markdown]
# ## 3. Feature Selection
# #### I. Modelo lineal inicial para Casas

# %%
model1 = smf.ols("lprice ~ tsqm + tsqm2 + bsqm + bsqm2 + dorm1 + dorm2 + dorm3 + dorm4 + dorm5 + bath1 + bath2 + bath3 + bath4 + bath5 + garage1 + garage2 + garage3 + garage4 + garage5 + house + dept + lot ", data=df )
model1_reg = model1.fit()
model1_reg.summary()

# %% [markdown]
# ### II. Modelo lineal para Departamentos

# %%
model2 = smf.ols("lprice ~ bsqm + dorm1 + dorm2 + dorm3 + dorm4 + dorm5 + bath1 + bath2 + bath3 + bath4 + bath5 + garages + house + dept", data=df )
model2_reg = model2.fit()
model2_reg.summary2()

# %%
df.loc[(df.lot==1)]

# %% [markdown]
# ### III. Modelo lineal para Lotes

# %%
model2 = smf.ols("lprice ~ tsqm + tsqm2 + bsqm + dorm1 + dorm2 + dorm3 + dorm4 + dorm5 + bath1 + bath2 + bath3 + bath4 + bath5 + garages + house + dept", data=df.loc[(df.lot==1)] )
model2_reg = model2.fit()
model2_reg.summary2()

# %% [markdown]
# ## 4. Modelo modificado
# ### I. Modelo lineal para Casas

# %%
model1 = smf.ols("lprice ~ tsqm + bsqm + dorm1 + dorm2 + dorm3 + dorm4 + dorm5 + bath1 + bath2 + bath3 + bath4 + bath5 + house + dept + lot + C(District)-1", data=df )
model1_reg = model1.fit()
model1_reg.summary()
# Out:
# E:\Miniconda3\envs\py36\lib\site-packages\statsmodels\regression\linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# E:\Miniconda3\envs\py36\lib\site-packages\statsmodels\base\model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# E:\Miniconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# E:\Miniconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# E:\Miniconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 lprice   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     15.11
# Date:                Wed, 28 Aug 2019   Prob (F-statistic):           8.43e-30
# Time:                        15:26:39   Log-Likelihood:                -240.28
# No. Observations:                 308   AIC:                             514.6
# Df Residuals:                     291   BIC:                             578.0
# Df Model:                          16
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# C(District)[Capital]         2.6931      0.070     38.635      0.000       2.556       2.830
# C(District)[Chimbas]         1.7672      0.133     13.293      0.000       1.506       2.029
# C(District)[Pocito]          2.0787      0.193     10.747      0.000       1.698       2.459
# C(District)[Rawson]          2.1222      0.089     23.860      0.000       1.947       2.297
# C(District)[Rivadavia]       2.4688      0.076     32.669      0.000       2.320       2.618
# C(District)[Santa Lucia]     2.4997      0.084     29.718      0.000       2.334       2.665
# tsqm                         0.0003      0.000      2.171      0.031    2.38e-05       0.000
# bsqm                         0.0023      0.001      3.172      0.002       0.001       0.004
# dorm1                        2.5593      0.091     28.106      0.000       2.380       2.739
# dorm2                        2.8573      0.079     36.220      0.000       2.702       3.013
# dorm3                        2.8448      0.064     44.207      0.000       2.718       2.971
# dorm4                        2.8499      0.093     30.545      0.000       2.666       3.034
# dorm5                        2.5184      0.159     15.825      0.000       2.205       2.832
# bath1                        2.3553      0.102     23.114      0.000       2.155       2.556
# bath2                        2.5468      0.100     25.405      0.000       2.350       2.744
# bath3                        2.8421      0.140     20.312      0.000       2.567       3.118
# bath4                        2.5965      0.257     10.084      0.000       2.090       3.103
# bath5                        3.2891      0.336      9.778      0.000       2.627       3.951
# house                        6.9048      0.101     68.542      0.000       6.706       7.103
# dept                         6.7250      0.088     76.556      0.000       6.552       6.898
# lot                               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      238.975   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9048.592
# Skew:                          -2.708   Prob(JB):                         0.00
# Kurtosis:                      28.995   Cond. No.                          inf
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### 2. Modelo lineal para departamentos

# %%
model2m = smf.ols("dfd.lprice ~  dfd.tsqm + dfd.tsqm2 + dfd.bsqm + dfd.bsqm2 + dfd.dorms + dfd.baths + dfd.garages", data=dfd )
model2m_reg = model2m.fit()
model2m_reg.summary2()

# %%
puntos = df[['long', 'lat']].values
triangulation = sp.spatial.Delaunay(puntos)
tri_2d = sp.spatial.delaunay_plot_2d(triangulation)

# %%
puntos_dept = dfd[['long', 'lat']].values
tri_dept = sp.spatial.Delaunay(puntos_dept)
tri_dept_2d = sp.spatial.delaunay_plot_2d(tri_dept)

# %% [markdown]
# A continuacion para hacer pruebas tomamos 10 observaciones unicamente

# %%
# Prueba de matriz de delaunay
dfp = df.iloc[205:235]

points_p = dfp[['long', 'lat']].values
tp = sp.spatial.Delaunay(points_p)
sp.spatial.delaunay_plot_2d(tp)

# %% [markdown]
# NO BORRAR TODAVÍA. QUEDA REVISAR EL CODIGO DE ABAJO QUE PUEDE DAR COMO RESULTADO UN LISTADO DE VECINOS

# %% [markdown]
# def find_neighbors(pindex, tp):
#     neighbors = list()
#     for simplex in tp.vertices:
#         if pindex in simplex:
#             neighbors.extend([simplex[i] for i in range(len(simplex)) if simplex[i] != pindex])
#     #now we just have to strip out all the dulicate indices and return the neighbors list:
#     return list(set(neighbors))

# %% [markdown]
# # Vecinos Delaunay
#
# El siguiente código busca un elemento del listado de puntos (_pindex_) y averigua cuáles son los vecinos.
# Nota: en este ejemplo estamos utilizando únicamente los *deptos* ya que el numero de obs es el menor.

# %%
import scipy.spatial
import numpy
import pylab

pindex = 5
points_d = dfp[['lat', 'long']].values
points_x = dfp['lat'].values
points_y = dfp['long'].values

td = sp.spatial.Delaunay(points_d)
neighbor_indices = td.neighbors[pindex]




pylab.plot(points_x, points_y, 'b.')
pylab.plot(points_x[pindex], points_y[pindex], 'dg')
pylab.plot([points_x[i] for i in neighbor_indices],
           [points_y[i] for i in neighbor_indices], 'ro')    

pylab.show()

# %% [markdown]
# ### ¿Qué más hace falta?
#
# Necesitamos armar la matriz ponderada NxN de vecinos de Delaunay, donde los vecinos toman valor 1.

# %% [markdown]
# # Mapa
#
# El siguiente mapa muestra los inmuebles con el precio relativo por m2 representado por el radio del círculo.
# - Casas en color Azul
# - Departamentos en color Rojo
# - Lotes en color Verde
#
# #### Falta graficar la triangulación de Delaunay para que se vean todos los triángulos que se generan.

# %%
mapa = folium.Map(location=[-31.539828,-68.514519], zoom_start=11)

# agregamos casas en color azul
for i in range(0,len(dfh)):
    folium.Circle(
        location = [dfh.iloc[i]['lat'], dfh.iloc[i]['long']],
        popup = dfh.iloc[i]['Type']+', '+str(dfh.iloc[i]['PriceArs'])+', '+str(dfh.iloc[i]['tsqm'])+', '+str(dfh.iloc[i]['bsqm']),
        radius = dfh.iloc[i]['pm2']/500,
        color = 'blue',
        fill = True,
        opacity = 0.89,
        fill_color = 'blue',
        stroke = True,
        weight = 1
        ).add_to(mapa)

# agregamos deptos en color rojo
for i in range(0,len(dfd)):
    folium.Circle(
        location = [dfd.iloc[i]['lat'], dfd.iloc[i]['long']],
        popup = dfd.iloc[i]['Type']+', '+str(dfd.iloc[i]['PriceArs'])+', '+str(dfd.iloc[i]['tsqm'])+', '+str(dfd.iloc[i]['bsqm']),
        radius = dfd.iloc[i]['pm2']/500,
        color = 'red',
        fill = True,
        opacity = 0.89,
        fill_color = 'red',
        stroke = True,
        weight = 1
        ).add_to(mapa)

# agregamos lotes en color verde
for i in range(0,len(dfl)):
    folium.Circle(
        location = [dfl.iloc[i]['lat'], dfl.iloc[i]['long']],
        popup = dfl.iloc[i]['Type']+', '+str(dfl.iloc[i]['PriceArs'])+', '+str(dfl.iloc[i]['tsqm'])+', '+str(dfl.iloc[i]['bsqm']),
        radius = dfl.iloc[i]['pm2']/500,
        color = 'green',
        fill = True,
        opacity = 0.89,
        fill_color = 'green',
        stroke = True,
        weight = 1
        ).add_to(mapa)

mapa
